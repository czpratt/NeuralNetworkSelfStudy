# %% [markdown]
# ## Version 1---let's go

# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import math
import random
# %matplotlib inline

# %%
words = open('../names.txt', 'r').read().splitlines()
chars = sorted(list(set(''.join(words))))
stoi = {s:i+1 for i, s in enumerate(chars)}
stoi['.'] = 0
itos = {i:s for s, i in stoi.items()}
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 words = open('../names.txt', 'r').read().splitlines()
#       2 chars = sorted(list(set(''.join(words))))
#       3 stoi = {s:i+1 for i, s in enumerate(chars)}
#
# File ~/py/lib/python3.10/site-packages/IPython/core/interactiveshell.py:308, in _modified_open(file, *args, **kwargs)
#     301 if file in {0, 1, 2}:
#     302     raise ValueError(
#     303         f"IPython won't let you open fd={file} by default "
#     304         "as it is likely to crash IPython. If you know what you are doing, "
#     305         "you can use builtins' open."
#     306     )
# --> 308 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../names.txt'
